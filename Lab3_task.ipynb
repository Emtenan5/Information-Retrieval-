# %% [markdown]
# <a href="https://colab.research.google.com/github/Emtenan5/Information-Retrieval-/blob/main/Lab3_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries
from bs4 import BeautifulSoup
import requests
import re

response = requests.get('https://practice.geeksforgeeks.org/courses')

# create soap object
soup = BeautifulSoup(response.content)

print(response.content)
# Out:
# b'<!DOCTYPE html><html><head><link rel="icon" href="https://media.geeksforgeeks.org/img-practice/favicon-1600291663.png" type="image/x-icon"/><meta http-equiv="Content-type" content="text/html;charset=UTF-8"/><meta charSet="UTF-8"/><meta name="keywords" content="programming, coding, online, code online, online judge, practice, run code, test, expected outcome, programming competition, programming contest, online programming, online computer programming"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1"/><title>Courses GeeksforGeeks | Interactive LIVE and Self-Paced Courses</title><meta name="description" content="Platform to practice programming problems. Solve company interview questions and improve your coding intellect"/><meta property="og:title" content="Courses GeeksforGeeks | Interactive LIVE and Self-Paced Courses"/><meta property="og:description" content="Platform to practice programming problems. Solve company interview questions and improve your coding intellect"/><meta property="og:image" content="https://media.geeksforgeeks.org/img-practice/gfg_200X200.png"/><meta property="og:image:alt" content="GeeksforGeeks"/><meta property="og:image:type" content="image/png"/><meta property="og:image:width" content="200"/><meta property="og:image:height" content="200"/><meta property="twitter:card" content="summary_large_image"/><meta property="twitter:title" content="Courses GeeksforGeeks | Interactive LIVE and Self-Paced Courses"/><meta property="twitter:description" content="Platform to practice programming problems. Solve company interview questions and improve your coding intellect"/><meta property="twitter:image" content="https://media.geeksforgeeks.org/img-practice/gfg_200X200.png"/><meta name="facebook-domain-verification" content="mxmpuqhvidl8dqsznrem8d8n0s4td0"/><meta name="next-head-count" content="19"/><link rel="preload" href="/_next/static/css/15ab87a6bb813062.css" as="style"/><link rel="stylesheet" href="/_next/static/css/15ab87a6bb813062.css" data-n-g=""/><link rel="preload" href="/_next/static/css/54d57618820427bd.css" as="style"/><link rel="stylesheet" href="/_next/static/css/54d57618820427bd.css" data-n-p=""/><link rel="preload" href="/_next/static/css/5e3bf2762e573791.css" as="style"/><link rel="stylesheet" href="/_next/static/css/5e3bf2762e573791.css" data-n-p=""/><noscript data-n-css=""></noscript><script defer="" nomodule="" src="/_next/static/chunks/polyfills-5cd94c89d3acac5f.js"></script><script src="/_next/static/chunks/webpack-f0f93509b16e3714.js" defer=""></script><script src="/_next/static/chunks/framework-79bce4a3a540b080.js" defer=""></script><script src="/_next/static/chunks/main-067dc35e1f7fd829.js" defer=""></script><script src="/_next/static/chunks/pages/_app-efdb5c2f7c805054.js" defer=""></script><script src="/_next/static/chunks/4857-aadf71b788140704.js" defer=""></script><script src="/_next/static/chunks/6420-2adf6f75c41b2d4f.js" defer=""></script><script src="/_next/static/chunks/5675-622b931e3b91258b.js" defer=""></script><script src="/_next/static/chunks/2769-e46bbfe7c3b5b3bb.js" defer=""></script><script src="/_next/static/chunks/1766-d7443797ecc70060.js" defer=""></script><script src="/_next/static/chunks/7990-f9354c1870e717a2.js" defer=""></script><script src="/_next/static/chunks/8060-a134565f92ce778f.js" defer=""></script><script src="/_next/static/chunks/211-0e2f03425d56e66b.js" defer=""></script><script src="/_next/static/chunks/pages/courses-b551648da9c42e8a.js" defer=""></script><script src="/_next/static/Bd8R0faO6DHD68X_daZvk/_buildManifest.js" defer=""></script><script src="/_next/static/Bd8R0faO6DHD68X_daZvk/_ssgManifest.js" defer=""></script><script src="/_next/static/Bd8R0faO6DHD68X_daZvk/_middlewareManifest.js" defer=""></script></head><body><div id="__next" data-reactroot=""><div><div class="defaultLoaderContainer"><div class="defaultLoader"><svg xmlns="http://www.w3.org/2000/svg" width="76.533" height="39.026" viewBox="0 0 76.533 39.02 ...
